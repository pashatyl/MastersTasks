# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# По аналогии с OCR:
# $$\Delta(y',y) + \langle \omega, \Psi(x, y') - \Psi(x, y) \rangle = $$
# $$\frac{1}{r} \sum_{t=1}^r \langle \omega^{(t)}, \phi(x, y'_t, y'_{t-1}) - \phi(x, y_t, y_{t-1} \rangle = $$
# $$\frac{1}{r} \sum_{t=1}^r \delta(t, y_t, y'_t, y_{t-1}, y'_{t-1})$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Заменим во втором алгоритме скалярные произведения(строки 2 и 6) на выведенное выше, а так же добавим прихранивание предыдущих $y_{t-1}$ и получим алгоритм ДП для многоклассового SGD, концовку же позаимствуем из 5-7 строк первого алгоритма)
